# %%
from Convert_Library import get_files_with_extension_advanced, convert_to_mp4

# %%
dir_path = "."
ext = "ts"

files = get_files_with_extension_advanced(dir_path, ext, recursive=False)
for file in files:
    # print(file[:-(len(ext)+1)])
    convert_to_mp4(file, output_mp4=file[:-(len(ext)+1)]+".mp4")
# Out:
# Converting: Five Nights at Freddy's 2.ts
#        →    Five Nights at Freddy's 2.mp4
# Success → Five Nights at Freddy's 2.mp4
# Converting: Watch Not Safe for Work.ts
#        →    Watch Not Safe for Work.mp4
# Success → Watch Not Safe for Work.mp4
