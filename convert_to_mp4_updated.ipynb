# %%
from Convert_Library import get_files_with_extension_advanced, convert_to_mp4

# %%
dir_path = "."
ext = "ts"

files = get_files_with_extension_advanced(dir_path, ext, recursive=False)
for file in files:
    # print(file[:-(len(ext)+1)])
    convert_to_mp4(file, output_mp4=file[:-(len(ext)+1)]+".mp4")
# Out:
# Converting: Watch Avatar- Aang, The Last Airbender (2026) Full HD Movie - SolarMovies.ts
#        →    Watch Avatar- Aang, The Last Airbender (2026) Full HD Movie - SolarMovies.mp4
# Success → Watch Avatar- Aang, The Last Airbender (2026) Full HD Movie - SolarMovies.mp4
